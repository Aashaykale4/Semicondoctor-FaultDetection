# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json

# %%
#uri
uri="mongodb+srv://<email>_db_user:<password>@cluster0.c477iiq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
#new client and connect
client=MongoClient(uri)

# %%
DATABASE_NAME="FaultDetect" 
COLLECTION_NAME="waferfault"

# %%
df=pd.read_csv("../notebooks/wafer_data.csv")

# %%
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2      0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3      0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4      0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
# 2        -1
# 3        -1
# 4        -1
#
# [5 rows x 592 columns]

# %%
df=df.drop(columns=["Unnamed: 0"],axis=1)

# %%
df.head()
# Out:
#    Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0   97.5822
# 1   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0   96.7700
# 2   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0  101.8644
# 3   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0  101.8644
# 4   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0  104.8856
#
#    Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0    0.1242    1.5300    -0.0279  ...         NaN      0.5004      0.0120
# 1    0.1230    1.3953     0.0084  ...         NaN      0.4994      0.0115
# 2    0.1220    1.3896     0.0138  ...         NaN      0.4987      0.0118
# 3    0.1220    1.4108    -0.0046  ...         NaN      0.4934      0.0123
# 4    0.1234    1.5094    -0.0046  ...         NaN      0.4987      0.0145
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2      0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3      0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4      0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
# 2        -1
# 3        -1
# 4        -1
#
# [5 rows x 591 columns]

# %%
json_record = list(json.loads(df.T.to_json()).values())

# %%
json_record[0]
# Out:
# {'Sensor-1': 2968.33,
#  'Sensor-2': 2476.58,
#  'Sensor-3': 2216.7333,
#  'Sensor-4': 1748.0885,
#  'Sensor-5': 1.1127,
#  'Sensor-6': 100.0,
#  'Sensor-7': 97.5822,
#  'Sensor-8': 0.1242,
#  'Sensor-9': 1.53,
#  'Sensor-10': -0.0279,
#  'Sensor-11': -0.004,
#  'Sensor-12': 0.9468,
#  'Sensor-13': 198.1219,
#  'Sensor-14': 0.0,
#  'Sensor-15': 6.0959,
#  'Sensor-16': 416.595,
#  'Sensor-17': 9.5431,
#  'Sensor-18': 0.9686,
#  'Sensor-19': 188.5788,
#  'Sensor-20': 12.4349,
#  'Sensor-21': 1.4188,
#  'Sensor-22': -5349.75,
#  'Sensor-23': 2663.5,
#  'Sensor-24': -3855.5,
#  'Sensor-25': 10126.6667,
#  'Sensor-26': 1.265,
#  'Sensor-27': 1.986,
#  'Sensor-28': 7.3152,
#  'Sensor-29': 75.4333,
#  'Sensor-30': 1.4,
#  'Sensor-31': 0.1018,
#  'Sensor-32': 3.3376,
#  'Sensor-33': 83.6583,
#  'Sensor-34': 8.5596,
#  'Sensor-35': 50.3882,
#  'Sensor-36': 64.4017,
#  'Sensor-37': 49.6118,
#  'Sensor-38': 66.0405,
#  'Sensor-39': 86.7827,
#  'Sensor-40': 119.4242,
#  'Sensor-41': 79.71,
#  'Sensor-42': 2.849,
#  'Sensor-43': 70.0,
#  'Sensor-44': 358.1082,
#  'Sensor-45': 10.2528,
#  'Sensor-46': 128.6364,
#  'Sensor-47': 727.6867,
#  'Sensor-48': 1.3467,
#  'Sensor-49': 142.3127,
#  'Sensor-50': 1.0,
#  'Sensor-51': 629.0573,
#  'Sensor-52': 203.8858,
#  'Sensor-53': 0.0,
#  'Sensor-54': 4.549,
#  'Sensor-55': 4.786,
#  'Sensor-56': 2887.0,
#  'Sensor-57': 0.9215,
#  'Sensor-58': 0.9506,
#  'Sensor-59': 4.6004,
#  'Sensor-60': 2.4182,
#  'Sensor-61': 358.8636,
#  'Sensor-62': 10.5336,
#  'Sensor-63': 111.0545,
#  'Sensor-64': 14.0237,
#  'Sensor-65': 17.5818,
#  'Sensor-66': 24.3727,
#  'Sensor-67': 703.314,
#  'Sensor-68': 1.1051,
#  'Sensor-69': 145.1155,
#  'Sensor-70': 1.0,
#  'Sensor-71': 615.0336,
#  'Sensor-72': 129.6649,
#  'Sensor-73': 146.7674,
#  'Sensor-74': 468.2663,
#  'Sensor-75': 0.0,
#  'Sensor-76': -0.0158,
#  'Sensor-77': -0.0631,
#  'Sensor-78': 0.0448,
#  'Sensor-79': -0.0053,
#  'Sensor-80': -0.012,
#  'Sensor-81': -0.0122,
#  'Sensor-82': -0.0453,
#  'Sensor-83': 0.1055,
#  'Sensor-84': 8.3051,
#  'Sensor-85': 0.1448,
#  'Sensor-86': 0.1083,
#  'Sensor-87': 2.4044,
#  'Sensor-88': 0.9906,
#  'Sensor-89': 1816.1957,
#  'Sensor-90': 0.1569,
#  'Sensor-91': 8966.2599,
#  'Sensor-92': -0.0468,
#  'Sensor-93': 0.0,
#  'Sensor-94': -0.0002,
#  'Sensor-95': 0.0,
#  'Sensor-96': 0.0,
#  'Sensor-97': -0.047,
#  'Sensor-98': 0.0,
#  'Sensor-99': -0.0493,
#  'Sensor-100': -0.0037,
#  'Sensor-101': 0.0002,
#  'Sensor-102': 0.0,
#  'Sensor-103': -0.0156,
#  'Sensor-104': -0.0105,
#  'Sensor-105': 0.0001,
#  'Sensor-106': 0.0,
#  'Sensor-107': 0.0002,
#  'Sensor-108': -0.0164,
#  'Sensor-109': -0.0644,
#  'Sensor-110': 0.9793,
#  'Sensor-111': 101.3766,
#  'Sensor-112': 232.4647,
#  'Sensor-113': 0.4601,
#  'Sensor-114': 0.9609,
#  'Sensor-115': 0.0,
#  'Sensor-116': 773.9219,
#  'Sensor-117': 0.9909,
#  'Sensor-118': 58.6677,
#  'Sensor-119': 0.6019,
#  'Sensor-120': 0.98,
#  'Sensor-121': 6.2643,
#  'Sensor-122': 15.79,
#  'Sensor-123': 4.817,
#  'Sensor-124': 15.84,
#  'Sensor-125': 15.8,
#  'Sensor-126': 1.475,
#  'Sensor-127': 2.76,
#  'Sensor-128': 0.7743,
#  'Sensor-129': 3.272,
#  'Sensor-130': -0.4258,
#  'Sensor-131': 0.7217,
#  'Sensor-132': 0.9968,
#  'Sensor-133': 2.2989,
#  'Sensor-134': 998.6109,
#  'Sensor-135': 37.8933,
#  'Sensor-136': 112.0,
#  'Sensor-137': 173.7,
#  'Sensor-138': 187.2,
#  'Sensor-139': 66.5,
#  'Sensor-140': 1062.2041,
#  'Sensor-141': 0.2942,
#  'Sensor-142': 0.0,
#  'Sensor-143': 6.31,
#  'Sensor-144': 0.0042,
#  'Sensor-145': 0.1481,
#  'Sensor-146': 0.076,
#  'Sensor-147': 0.0329,
#  'Sensor-148': 0.0266,
#  'Sensor-149': 7.6634,
#  'Sensor-150': 0.0,
#  'Sensor-151': 4.901,
#  'Sensor-152': 7.409,
#  'Sensor-153': 0.3048,
#  'Sensor-154': 0.0134,
#  'Sensor-155': 7.4377,
#  'Sensor-156': 0.22,
#  'Sensor-157': 0.0397,
#  'Sensor-158': None,
#  'Sensor-159': None,
#  'Sensor-160': 461.0,
#  'Sensor-161': 375.0,
#  'Sensor-162': 1960.0,
#  'Sensor-163': 1711.0,
#  'Sensor-164': 0.119,
#  'Sensor-165': 0.089,
#  'Sensor-166': 0.22,
#  'Sensor-167': 1.7,
#  'Sensor-168': 2.6,
#  'Sensor-169': 0.164,
#  'Sensor-170': 0.344,
#  'Sensor-171': 0.5693,
#  'Sensor-172': 0.0988,
#  'Sensor-173': 0.2275,
#  'Sensor-174': 0.4025,
#  'Sensor-175': 0.2275,
#  'Sensor-176': 0.6599,
#  'Sensor-177': 0.3532,
#  'Sensor-178': 0.117,
#  'Sensor-179': 0.0,
#  'Sensor-180': 0.0,
#  'Sensor-181': 19.31,
#  'Sensor-182': 0.496,
#  'Sensor-183': 5.58,
#  'Sensor-184': 25.466,
#  'Sensor-185': 0.1801,
#  'Sensor-186': 2.29,
#  'Sensor-187': 0.0,
#  'Sensor-188': 18.48,
#  'Sensor-189': 55.026,
#  'Sensor-190': 0.0,
#  'Sensor-191': 0.0,
#  'Sensor-192': 0.0,
#  'Sensor-193': 0.0,
#  'Sensor-194': 0.0,
#  'Sensor-195': 0.0,
#  'Sensor-196': 0.267,
#  'Sensor-197': 4.48,
#  'Sensor-198': 18.99,
#  'Sensor-199': 0.377,
#  'Sensor-200': 5.05,
#  'Sensor-201': 22.17,
#  'Sensor-202': 4.48,
#  'Sensor-203': 7.592,
#  'Sensor-204': 31.051,
#  'Sensor-205': 0.0809,
#  'Sensor-206': 7.39,
#  'Sensor-207': 0.0,
#  'Sensor-208': 22.17,
#  'Sensor-209': 99.106,
#  'Sensor-210': 0.0,
#  'Sensor-211': 0.0797,
#  'Sensor-212': 0.1163,
#  'Sensor-213': 0.0592,
#  'Sensor-214': 0.0296,
#  'Sensor-215': 0.0916,
#  'Sensor-216': 0.0135,
#  'Sensor-217': 0.0374,
#  'Sensor-218': 0.0508,
#  'Sensor-219': 3.5914,
#  'Sensor-220': 0.0015,
#  'Sensor-221': 0.0104,
#  'Sensor-222': 0.0563,
#  'Sensor-223': 0.0008,
#  'Sensor-224': 156.333,
#  'Sensor-225': 0.0283,
#  'Sensor-226': 983.7998,
#  'Sensor-227': 0.0,
#  'Sensor-228': 0.0096,
#  'Sensor-229': 0.014,
#  'Sensor-230': 0.0,
#  'Sensor-231': 0.0,
#  'Sensor-232': 0.0,
#  'Sensor-233': 0.0,
#  'Sensor-234': 0.0,
#  'Sensor-235': 0.0,
#  'Sensor-236': 0.0,
#  'Sensor-237': 0.0,
#  'Sensor-238': 0.0,
#  'Sensor-239': 0.0045,
#  'Sensor-240': 0.0044,
#  'Sensor-241': 0.0,
#  'Sensor-242': 0.0,
#  'Sensor-243': 0.0,
#  'Sensor-244': 0.0,
#  'Sensor-245': 0.0028,
#  'Sensor-246': 1.0247,
#  'Sensor-247': 3.6149,
#  'Sensor-248': 0.0193,
#  'Sensor-249': 0.0192,
#  'Sensor-250': 0.0,
#  'Sensor-251': 100.1752,
#  'Sensor-252': 0.0008,
#  'Sensor-253': 2.3929,
#  'Sensor-254': 0.0362,
#  'Sensor-255': 0.0042,
#  'Sensor-256': 0.2092,
#  'Sensor-257': 0.0,
#  'Sensor-258': 0.0,
#  'Sensor-259': 0.0,
#  'Sensor-260': 0.0,
#  'Sensor-261': 0.0,
#  'Sensor-262': 0.0,
#  'Sensor-263': 0.0,
#  'Sensor-264': 0.0,
#  'Sensor-265': 0.0,
#  'Sensor-266': 0.0,
#  'Sensor-267': 0.0,
#  'Sensor-268': 0.0911,
#  'Sensor-269': 12.117,
#  'Sensor-270': 3.628,
#  'Sensor-271': 30.9697,
#  'Sensor-272': 50.1268,
#  'Sensor-273': 58.1409,
#  'Sensor-274': 21.3926,
#  'Sensor-275': 308.498,
#  'Sensor-276': 0.0985,
#  'Sensor-277': 0.0,
#  'Sensor-278': 1.9866,
#  'Sensor-279': 0.0013,
#  'Sensor-280': 0.0488,
#  'Sensor-281': 0.0228,
#  'Sensor-282': 0.0087,
#  'Sensor-283': 0.0089,
#  'Sensor-284': 2.5665,
#  'Sensor-285': 0.0,
#  'Sensor-286': 1.5831,
#  'Sensor-287': 2.2461,
#  'Sensor-288': 0.094,
#  'Sensor-289': 0.0043,
#  'Sensor-290': 2.5168,
#  'Sensor-291': 0.0584,
#  'Sensor-292': 0.0139,
#  'Sensor-293': None,
#  'Sensor-294': None,
#  'Sensor-295': 199.8506,
#  'Sensor-296': 176.9717,
#  'Sensor-297': 886.6192,
#  'Sensor-298': 880.8657,
#  'Sensor-299': 0.0519,
#  'Sensor-300': 0.0432,
#  'Sensor-301': 0.0926,
#  'Sensor-302': 0.7089,
#  'Sensor-303': 0.7842,
#  'Sensor-304': 0.047,
#  'Sensor-305': 0.1018,
#  'Sensor-306': 0.2215,
#  'Sensor-307': 0.0388,
#  'Sensor-308': 0.0922,
#  'Sensor-309': 0.1542,
#  'Sensor-310': 0.0921,
#  'Sensor-311': 0.2756,
#  'Sensor-312': 0.1422,
#  'Sensor-313': 0.0482,
#  'Sensor-314': 0.0,
#  'Sensor-315': 0.0,
#  'Sensor-316': 0.0,
#  'Sensor-317': 5.96,
#  'Sensor-318': 0.1322,
#  'Sensor-319': 1.6683,
#  'Sensor-320': 8.222,
#  'Sensor-321': 0.0561,
#  'Sensor-322': 0.9501,
#  'Sensor-323': 0.0,
#  'Sensor-324': 5.6734,
#  'Sensor-325': 15.8699,
#  'Sensor-326': 0.0,
#  'Sensor-327': 0.0,
#  'Sensor-328': 0.0,
#  'Sensor-329': 0.0,
#  'Sensor-330': 0.0,
#  'Sensor-331': 0.0,
#  'Sensor-332': 0.0871,
#  'Sensor-333': 1.3214,
#  'Sensor-334': 5.9317,
#  'Sensor-335': 0.1372,
#  'Sensor-336': 1.5617,
#  'Sensor-337': 8.6863,
#  'Sensor-338': 1.3214,
#  'Sensor-339': 2.1729,
#  'Sensor-340': 9.8719,
#  'Sensor-341': 0.0211,
#  'Sensor-342': 2.3748,
#  'Sensor-343': 0.0,
#  'Sensor-344': 7.4814,
#  'Sensor-345': 36.104,
#  'Sensor-346': 6.2091,
#  'Sensor-347': 2.7828,
#  'Sensor-348': 0.0,
#  'Sensor-349': 0.0236,
#  'Sensor-350': 0.0479,
#  'Sensor-351': 0.029,
#  'Sensor-352': 0.0146,
#  'Sensor-353': 0.0228,
#  'Sensor-354': 0.0056,
#  'Sensor-355': 0.0173,
#  'Sensor-356': 0.0214,
#  'Sensor-357': 1.1627,
#  'Sensor-358': 0.0005,
#  'Sensor-359': 0.0029,
#  'Sensor-360': 0.0174,
#  'Sensor-361': 0.0003,
#  'Sensor-362': 47.2458,
#  'Sensor-363': 0.008,
#  'Sensor-364': 328.5346,
#  'Sensor-365': 0.0,
#  'Sensor-366': 0.0028,
#  'Sensor-367': 0.0041,
#  'Sensor-368': 0.0018,
#  'Sensor-369': 0.0029,
#  'Sensor-370': 0.0,
#  'Sensor-371': 0.0,
#  'Sensor-372': 0.0,
#  'Sensor-373': 0.0,
#  'Sensor-374': 0.0,
#  'Sensor-375': 0.0,
#  'Sensor-376': 0.0,
#  'Sensor-377': 0.0014,
#  'Sensor-378': 0.0016,
#  'Sensor-379': 0.0,
#  'Sensor-380': 0.0,
#  'Sensor-381': 0.0,
#  'Sensor-382': 0.0,
#  'Sensor-383': 0.0009,
#  'Sensor-384': 0.3616,
#  'Sensor-385': 0.9081,
#  'Sensor-386': 0.0062,
#  'Sensor-387': 0.0067,
#  'Sensor-388': 0.0,
#  'Sensor-389': 30.6917,
#  'Sensor-390': 0.0002,
#  'Sensor-391': 0.6171,
#  'Sensor-392': 0.0103,
#  'Sensor-393': 0.0016,
#  'Sensor-394': 0.0744,
#  'Sensor-395': 0.0,
#  'Sensor-396': 0.0,
#  'Sensor-397': 0.0,
#  'Sensor-398': 0.0,
#  'Sensor-399': 0.0,
#  'Sensor-400': 0.0,
#  'Sensor-401': 0.0,
#  'Sensor-402': 0.0,
#  'Sensor-403': 0.0,
#  'Sensor-404': 0.0,
#  'Sensor-405': 0.0,
#  'Sensor-406': 0.0336,
#  'Sensor-407': 3.684,
#  'Sensor-408': 1.4148,
#  'Sensor-409': 5.1519,
#  'Sensor-410': 5.8518,
#  'Sensor-411': 7.5588,
#  'Sensor-412': 2.9999,
#  'Sensor-413': 60.7637,
#  'Sensor-414': 26.436,
#  'Sensor-415': 0.0,
#  'Sensor-416': 6.4663,
#  'Sensor-417': 3.3812,
#  'Sensor-418': 9.68,
#  'Sensor-419': 272.0358,
#  'Sensor-420': 821.2168,
#  'Sensor-421': 2.809,
#  'Sensor-422': 3.868,
#  'Sensor-423': 0.0,
#  'Sensor-424': 80.3982,
#  'Sensor-425': 1.7785,
#  'Sensor-426': 3.1943,
#  'Sensor-427': 1.384,
#  'Sensor-428': 3.9441,
#  'Sensor-429': 1.7692,
#  'Sensor-430': 2.7954,
#  'Sensor-431': 8.6172,
#  'Sensor-432': 14.0792,
#  'Sensor-433': 50.8365,
#  'Sensor-434': 16.896,
#  'Sensor-435': 9.4071,
#  'Sensor-436': 4.4814,
#  'Sensor-437': 3.0074,
#  'Sensor-438': 2.2536,
#  'Sensor-439': 185.7143,
#  'Sensor-440': 161.1354,
#  'Sensor-441': 10.3069,
#  'Sensor-442': 0.6805,
#  'Sensor-443': 1.1541,
#  'Sensor-444': 0.4515,
#  'Sensor-445': 0.625,
#  'Sensor-446': 0.4586,
#  'Sensor-447': 0.9992,
#  'Sensor-448': 0.407,
#  'Sensor-449': 0.098,
#  'Sensor-450': 0.0,
#  'Sensor-451': 0.0,
#  'Sensor-452': 0.0,
#  'Sensor-453': 5.3922,
#  'Sensor-454': 4.8377,
#  'Sensor-455': 4.3378,
#  'Sensor-456': 3.4996,
#  'Sensor-457': 13.3755,
#  'Sensor-458': 1.6091,
#  'Sensor-459': 0.0,
#  'Sensor-460': 2.9377,
#  'Sensor-461': 26.9886,
#  'Sensor-462': 0.0,
#  'Sensor-463': 0.0,
#  'Sensor-464': 0.0,
#  'Sensor-465': 0.0,
#  'Sensor-466': 0.0,
#  'Sensor-467': 0.0,
#  'Sensor-468': 5.8039,
#  'Sensor-469': 185.2632,
#  'Sensor-470': 5.2917,
#  'Sensor-471': 3.579,
#  'Sensor-472': 4.5473,
#  'Sensor-473': 158.09,
#  'Sensor-474': 25.4809,
#  'Sensor-475': 31.1496,
#  'Sensor-476': 4.415,
#  'Sensor-477': 7.3233,
#  'Sensor-478': 5.0925,
#  'Sensor-479': 0.0,
#  'Sensor-480': 3.6047,
#  'Sensor-481': 76.4324,
#  'Sensor-482': 0.0,
#  'Sensor-483': 503.6335,
#  'Sensor-484': 184.3837,
#  'Sensor-485': 132.1429,
#  'Sensor-486': 561.1374,
#  'Sensor-487': 764.9269,
#  'Sensor-488': 110.4294,
#  'Sensor-489': 82.5152,
#  'Sensor-490': 48.1517,
#  'Sensor-491': 43.2437,
#  'Sensor-492': 1.0362,
#  'Sensor-493': 9.6238,
#  'Sensor-494': 2.34,
#  'Sensor-495': 0.0769,
#  'Sensor-496': 8.6077,
#  'Sensor-497': 18.009,
#  'Sensor-498': 10.9722,
#  'Sensor-499': 0.0,
#  'Sensor-500': 0.0,
#  'Sensor-501': 0.0,
#  'Sensor-502': 0.0,
#  'Sensor-503': 0.0,
#  'Sensor-504': 0.0,
#  'Sensor-505': 0.0,
#  'Sensor-506': 0.0,
#  'Sensor-507': 0.0,
#  'Sensor-508': 0.0,
#  'Sensor-509': 0.0,
#  'Sensor-510': 0.0,
#  'Sensor-511': 43.0108,
#  'Sensor-512': 0.0,
#  'Sensor-513': 0.0,
#  'Sensor-514': 0.0,
#  'Sensor-515': 0.0,
#  'Sensor-516': 0.0,
#  'Sensor-517': 0.2829,
#  'Sensor-518': 1.0108,
#  'Sensor-519': 1.555,
#  'Sensor-520': 4.2022,
#  'Sensor-521': 1.995,
#  'Sensor-522': 0.0,
#  'Sensor-523': 12.9438,
#  'Sensor-524': 0.0825,
#  'Sensor-525': 4.0788,
#  'Sensor-526': 6.0161,
#  'Sensor-527': 0.4296,
#  'Sensor-528': 3.3392,
#  'Sensor-529': 0.0,
#  'Sensor-530': 0.0,
#  'Sensor-531': 0.0,
#  'Sensor-532': 0.0,
#  'Sensor-533': 0.0,
#  'Sensor-534': 0.0,
#  'Sensor-535': 0.0,
#  'Sensor-536': 0.0,
#  'Sensor-537': 0.0,
#  'Sensor-538': 0.0,
#  'Sensor-539': 0.0,
#  'Sensor-540': 3.9638,
#  'Sensor-541': 1.2134,
#  'Sensor-542': 9.5742,
#  'Sensor-543': 0.1083,
#  'Sensor-544': 0.0104,
#  'Sensor-545': 0.0029,
#  'Sensor-546': 9.6238,
#  'Sensor-547': None,
#  'Sensor-548': None,
#  'Sensor-549': None,
#  'Sensor-550': None,
#  'Sensor-551': None,
#  'Sensor-552': None,
#  'Sensor-553': None,
#  'Sensor-554': None,
#  'Sensor-555': None,
#  'Sensor-556': None,
#  'Sensor-557': None,
#  'Sensor-558': None,
#  'Sensor-559': 0.9815,
#  'Sensor-560': 0.5123,
#  'Sensor-561': 0.0909,
#  'Sensor-562': 52.1953,
#  'Sensor-563': 265.37,
#  'Sensor-564': 0.717,
#  'Sensor-565': 5.18,
#  'Sensor-566': 0.2259,
#  'Sensor-567': 2.0235,
#  'Sensor-568': 0.0886,
#  'Sensor-569': 1.952,
#  'Sensor-570': 31.5069,
#  'Sensor-571': 534.1482,
#  'Sensor-572': 1.6633,
#  'Sensor-573': 10.92,
#  'Sensor-574': 0.2937,
#  'Sensor-575': 3.7983,
#  'Sensor-576': 0.0853,
#  'Sensor-577': 2.0444,
#  'Sensor-578': 17.6552,
#  'Sensor-579': None,
#  'Sensor-580': None,
#  'Sensor-581': None,
#  'Sensor-582': None,
#  'Sensor-583': 0.5004,
#  'Sensor-584': 0.012,
#  'Sensor-585': 0.0033,
#  'Sensor-586': 2.4069,
#  'Sensor-587': 0.0545,
#  'Sensor-588': 0.0184,
#  'Sensor-589': 0.0055,
#  'Sensor-590': 33.7876,
#  'Good/Bad': -1.0}

# %%
#uplad_json data mongodb
# client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
# Out:
# InsertManyResult([ObjectId('68c42d10f099fb074bc8c28e'), ObjectId('68c42d10f099fb074bc8c28f'), ObjectId('68c42d10f099fb074bc8c290'), ObjectId('68c42d10f099fb074bc8c291'), ObjectId('68c42d10f099fb074bc8c292'), ObjectId('68c42d10f099fb074bc8c293'), ObjectId('68c42d10f099fb074bc8c294'), ObjectId('68c42d10f099fb074bc8c295'), ObjectId('68c42d10f099fb074bc8c296'), ObjectId('68c42d10f099fb074bc8c297'), ObjectId('68c42d10f099fb074bc8c298'), ObjectId('68c42d10f099fb074bc8c299'), ObjectId('68c42d10f099fb074bc8c29a'), ObjectId('68c42d10f099fb074bc8c29b'), ObjectId('68c42d10f099fb074bc8c29c'), ObjectId('68c42d10f099fb074bc8c29d'), ObjectId('68c42d10f099fb074bc8c29e'), ObjectId('68c42d10f099fb074bc8c29f'), ObjectId('68c42d10f099fb074bc8c2a0'), ObjectId('68c42d10f099fb074bc8c2a1'), ObjectId('68c42d10f099fb074bc8c2a2'), ObjectId('68c42d10f099fb074bc8c2a3'), ObjectId('68c42d10f099fb074bc8c2a4'), ObjectId('68c42d10f099fb074bc8c2a5'), ObjectId('68c42d10f099fb074bc8c2a6'), ObjectId('68c42d10f099fb074bc8c2a7'), ObjectId('68c42d10f099fb074bc8c2a8'), ObjectId('68c42d10f099fb074bc8c2a9'), ObjectId('68c42d10f099fb074bc8c2aa'), ObjectId('68c42d10f099fb074bc8c2ab'), ObjectId('68c42d10f099fb074bc8c2ac'), ObjectId('68c42d10f099fb074bc8c2ad'), ObjectId('68c42d10f099fb074bc8c2ae'), ObjectId('68c42d10f099fb074bc8c2af'), ObjectId('68c42d10f099fb074bc8c2b0'), ObjectId('68c42d10f099fb074bc8c2b1'), ObjectId('68c42d10f099fb074bc8c2b2'), ObjectId('68c42d10f099fb074bc8c2b3'), ObjectId('68c42d10f099fb074bc8c2b4'), ObjectId('68c42d10f099fb074bc8c2b5'), ObjectId('68c42d10f099fb074bc8c2b6'), ObjectId('68c42d10f099fb074bc8c2b7'), ObjectId('68c42d10f099fb074bc8c2b8'), ObjectId('68c42d10f099fb074bc8c2b9'), ObjectId('68c42d10f099fb074bc8c2ba'), ObjectId('68c42d10f099fb074bc8c2bb'), ObjectId('68c42d10f099fb074bc8c2bc'), ObjectId('68c42d10f099fb074bc8c2bd'), ObjectId('68c42d10f099fb074bc8c2be'), ObjectId('68c42d10f099fb074bc8c2bf'), ObjectId('68c42d10f099fb074bc8c2c0'), ObjectId('68c42d10f099fb074bc8c2c1'), ObjectId('68c42d10f099fb074bc8c2c2'), ObjectId('68c42d10f099fb074bc8c2c3'), ObjectId('68c42d10f099fb074bc8c2c4'), ObjectId('68c42d10f099fb074bc8c2c5'), ObjectId('68c42d10f099fb074bc8c2c6'), ObjectId('68c42d10f099fb074bc8c2c7'), ObjectId('68c42d10f099fb074bc8c2c8'), ObjectId('68c42d10f099fb074bc8c2c9'), ObjectId('68c42d10f099fb074bc8c2ca'), ObjectId('68c42d10f099fb074bc8c2cb'), ObjectId('68c42d10f099fb074bc8c2cc'), ObjectId('68c42d10f099fb074bc8c2cd'), ObjectId('68c42d10f099fb074bc8c2ce'), ObjectId('68c42d10f099fb074bc8c2cf'), ObjectId('68c42d10f099fb074bc8c2d0'), ObjectId('68c42d10f099fb074bc8c2d1'), ObjectId('68c42d10f099fb074bc8c2d2'), ObjectId('68c42d10f099fb074bc8c2d3'), ObjectId('68c42d10f099fb074bc8c2d4'), ObjectId('68c42d10f099fb074bc8c2d5'), ObjectId('68c42d10f099fb074bc8c2d6'), ObjectId('68c42d10f099fb074bc8c2d7'), ObjectId('68c42d10f099fb074bc8c2d8'), ObjectId('68c42d10f099fb074bc8c2d9'), ObjectId('68c42d10f099fb074bc8c2da'), ObjectId('68c42d10f099fb074bc8c2db'), ObjectId('68c42d10f099fb074bc8c2dc'), ObjectId('68c42d10f099fb074bc8c2dd'), ObjectId('68c42d10f099fb074bc8c2de'), ObjectId('68c42d10f099fb074bc8c2df'), ObjectId('68c42d10f099fb074bc8c2e0'), ObjectId('68c42d10f099fb074bc8c2e1'), ObjectId('68c42d10f099fb074bc8c2e2'), ObjectId('68c42d10f099fb074bc8c2e3'), ObjectId('68c42d10f099fb074bc8c2e4'), ObjectId('68c42d10f099fb074bc8c2e5'), ObjectId('68c42d10f099fb074bc8c2e6'), ObjectId('68c42d10f099fb074bc8c2e7'), ObjectId('68c42d10f099fb074bc8c2e8'), ObjectId('68c42d10f099fb074bc8c2e9'), ObjectId('68c42d10f099fb074bc8c2ea'), ObjectId('68c42d10f099fb074bc8c2eb'), ObjectId('68c42d10f099fb074bc8c2ec'), ObjectId('68c42d10f099fb074bc8c2ed'), ObjectId('68c42d10f099fb074bc8c2ee'), ObjectId('68c42d10f099fb074bc8c2ef'), ObjectId('68c42d10f099fb074bc8c2f0'), ObjectId('68c42d10f099fb074bc8c2f1')], acknowledged=True)
